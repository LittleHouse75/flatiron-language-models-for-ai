# %% [markdown]
# ![Banner](https://github.com/LittleHouse75/flatiron-resources/raw/main/NevitsBanner.png)
# ----
# # Project Setup & Introduction
# ----
#
# This notebook introduces the project, the dataset (SAMSum), the modeling goals, and the high-level structure of the full workflow. It also outlines environment assumptions, directory layout, and how to run the rest of the notebooks independently.
#
# This is Notebook **00** in the series:
#
# - **00_intro_and_setup.ipynb** (this file)
# - 01_data_exploration.ipynb
# - 02_experiment_bert_gpt2.ipynb
# - 03_experiment_bart_t5.ipynb
# - 04_experiment_frontier_llms.ipynb
# - 05_evaluation_and_analysis.ipynb
# - 06_conclusions.ipynb
#
# Each notebook is designed to run independently without relying on previous runtime state.

# %% [markdown]
# ## 1. Project Overview
#
# Acme Communications wants an automated way to summarize long, messy chat conversations.
# The goal of this project is to:
#
# - Load and explore the SAMSum dataset.
# - Fine-tune summarization models (BERT→GPT-2, BART, T5).
# - Evaluate summarization performance with ROUGE.
# - Compare against frontier LLMs (via API) used as zero-shot summarizers.
# - Produce business-ready insights about quality, latency, and deployability.
#
# This notebook sets the stage for all of that.
